# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
hf_data_2021 = pd.read_csv('../data/hfi_cc_2021.csv')

# %%
hf_data_2018 = hf_data_2021[hf_data_2021['year'] == 2018]

# %%
hf_data_2018.describe()
# Out:
#          year    hf_score     hf_rank  hf_quartile  pf_rol_procedural  \
# count   165.0  162.000000  162.000000   162.000000         119.000000
# mean   2018.0    7.151420   81.345679     2.512346           5.227983
# std       0.0    1.226465   46.923000     1.121432           2.108502
# min    2018.0    3.830000    1.000000     1.000000           1.000000
# 25%    2018.0    6.345000   41.250000     2.000000           3.600000
# 50%    2018.0    7.230000   81.000000     3.000000           4.940000
# 75%    2018.0    8.175000  121.750000     3.750000           6.725000
# max    2018.0    9.140000  162.000000     4.000000           9.580000
#
#        pf_rol_civil  pf_rol_criminal      pf_rol  pf_ss_homicide  \
# count    119.000000       119.000000  165.000000      163.000000
# mean       5.502857         4.714118    5.061818        8.126810
# std        1.352452         1.593335    1.654793        2.519324
# min        2.560000         1.290000    1.540000        0.000000
# 25%        4.510000         3.545000    3.870000        7.785000
# 50%        5.320000         4.350000    4.710000        9.270000
# 75%        6.285000         5.660000    6.200000        9.635000
# max        8.610000         8.330000    8.800000        9.940000
#
#        pf_ss_disappearances_disap  ...  ef_regulation_business_adm  \
# count                  162.000000  ...                  148.000000
# mean                     8.549383  ...                    4.165405
# std                      2.984541  ...                    1.255894
# min                      0.000000  ...                    1.140000
# 25%                     10.000000  ...                    3.307500
# 50%                     10.000000  ...                    4.185000
# 75%                     10.000000  ...                    4.900000
# max                     10.000000  ...                    7.440000
#
#        ef_regulation_business_bureaucracy  ef_regulation_business_start  \
# count                          162.000000                    162.000000
# mean                             5.378889                      9.215247
# std                              2.572886                      0.858977
# min                              0.000000                      4.440000
# 25%                              3.560000                      9.070000
# 50%                              5.780000                      9.525000
# 75%                              7.110000                      9.710000
# max                             10.000000                      9.980000
#
#        ef_regulation_business_bribes  ef_regulation_business_licensing  \
# count                     159.000000                        159.000000
# mean                        5.761950                          8.379623
# std                         2.399007                          1.146112
# min                         0.770000                          4.980000
# 25%                         3.920000                          7.835000
# 50%                         5.950000                          8.630000
# 75%                         7.455000                          9.245000
# max                         9.930000                         10.000000
#
#        ef_regulation_business_compliance  ef_regulation_business  \
# count                         162.000000              162.000000
# mean                            7.330000                6.728333
# std                             1.802141                1.219756
# min                             0.000000                2.080000
# 25%                             6.925000                6.090000
# 50%                             7.705000                6.790000
# 75%                             8.430000                7.572500
# max                             9.750000                9.340000
#
#        ef_regulation    ef_score     ef_rank
# count     162.000000  162.000000  162.000000
# mean        7.107346    6.922531   81.203704
# std         1.042951    0.958407   46.974308
# min         2.550000    3.310000    1.000000
# 25%         6.550000    6.302500   39.750000
# 50%         7.135000    7.070000   81.000000
# 75%         7.810000    7.677500  121.750000
# max         9.430000    9.030000  162.000000
#
# [8 rows x 122 columns]

# %%
print(hf_data_2018['ISO'])
# Out:
# 165    ALB
# 166    DZA
# 167    AGO
# 168    ARG
# 169    ARM
#       ...
# 325    VEN
# 326    VNM
# 327    YEM
# 328    ZMB
# 329    ZWE
# Name: ISO, Length: 165, dtype: object

# %%
desired_list = ['countries', 'ISO', 'pf_score', 'ef_score']

pf_ef_comparison_2018 = hf_data_2018[desired_list]

# %%
print(pf_ef_comparison_2018)
# Out:
#          countries  ISO  pf_score  ef_score
# 165        Albania  ALB      8.43      7.78
# 166        Algeria  DZA      5.48      4.83
# 167         Angola  AGO      6.48      4.86
# 168      Argentina  ARG      8.77      5.88
# 169        Armenia  ARM      8.06      7.94
# ..             ...  ...       ...       ...
# 325  Venezuela, RB  VEN      4.93      3.31
# 326        Vietnam  VNM      5.68      6.24
# 327    Yemen, Rep.  YEM      3.10      5.44
# 328         Zambia  ZMB      6.85      7.20
# 329       Zimbabwe  ZWE      6.18      5.31
#
# [165 rows x 4 columns]

# %%
sns.scatterplot(data=pf_ef_comparison_2018, x= 'pf_score', y= 'ef_score')

plt.xlabel('Personal Freedom Score')
plt.ylabel('Economic Freedom Score')
plt.title('Relationship between Personal and Economic Freedom 2018')
# Out:
# Text(0.5, 1.0, 'Relationship between Personal and Economic Freedom 2018')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(20, 20))

sns.scatterplot(data=hf_data_2018, x='pf_score', y='ef_score')
plt.xlabel('Personal Freedom Score')
plt.ylabel('Economic Freedom Score')
plt.title('Relationship between Personal Freedom and Economic Freedom (2018)')

# Reset the index of the DataFrame
hf_data_2018_reset = hf_data_2018.reset_index()

# Add country labels as annotations
for i in range(len(hf_data_2018_reset)):
    plt.annotate(hf_data_2018_reset['ISO'][i], (hf_data_2018_reset['pf_score'][i], hf_data_2018_reset['ef_score'][i]))

plt.show()
